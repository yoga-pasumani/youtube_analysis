# %% [markdown]
# <a href="https://colab.research.google.com/github/yoga-pasumani/youtube_analysis/blob/main/Youtube_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/youtubers_df.csv')
df

# %%
df.info()

# %%
#data exploration
df.isnull().sum()

# %%
df.fillna('None')

# %%
df.duplicated().sum()

# %%
df.head()

# %%
#Finding Outliers using Boxplot
sns.boxplot(df,x='Rank')
plt.title("Outliers")

# %%
#Trend Analyisis
"""Identify trends among the top YouTube streamers. Which categories are the most popular?
   Is there a correlation between the number of subscribers and the number of likes or comments?"""
plt.figure(figsize=(12,8))
x=df.groupby('Categories')['Suscribers'].sum().plot(kind='bar')
plt.title("Category vs Subscribers")

# %%
df1=df[['Suscribers','Likes','Comments']]
sns.heatmap(df1.corr(),annot=True)

# %%
fig = px.histogram(df, x='Visits', nbins=50, title='Distribution of Visits')
fig.show()

# %%
df[['Suscribers', 'Visits', 'Likes', 'Comments']].mean().plot(kind='bar')
plt.title('Average Metrics')
plt.ylabel('Average')

# %%
category_counts = df['Categories'].value_counts()
print(category_counts)

category_metrics = df.groupby('Categories')[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()
print(category_metrics)

overall_average = df[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()
exceptional_categories = category_metrics[category_metrics > overall_average]
print(exceptional_categories)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Suscribers', y='Links', data=df, color = 'royalblue')
plt.title('Subscribers vs Brand Collaborations')
plt.xlabel('Subscribers')
plt.ylabel('Brand Collaborations')
plt.show()

# %%
avg_metrics = df[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()
above_average = df[['Suscribers', 'Visits', 'Likes', 'Comments']] > avg_metrics
top_performers = df[above_average.all(axis=1)]
print(top_performers)

# %%
# !apt-get install git -qq  # Install Git
# !git config --global user.email "yogapavi2002@gmail.com"  # Set email
# !git config --global user.name "yoga-pasumani"    # Set username

# %%
# !git clone https://github.com/your-username/youtube_analysis  # Replace with your repo URL
# %cd your-repo-name  # Navigate into the repo
